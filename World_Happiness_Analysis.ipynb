# %% [markdown]
# # 🌍 Happiness Data Analysis
#
# This project analyzes the happiness levels of 8 countries using a small CSV dataset.
# We explore the relationships between happiness and factors like GDP and life expectancy.
# Visualizations help understand trends and rankings.
#
#   Focus:
# - Correlation between variables
# - Country ranking by happiness
# - Simple conclusions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')
df = pd.read_csv('happiness_sample.csv')
df.head()
# Out:
#        Country  Happiness_Score  GDP_per_Capita  Health_Life_Expectancy  \
# 0       Norway            7.537           1.616                   0.796
# 1      Denmark            7.522           1.482                   0.792
# 2      Iceland            7.504           1.480                   0.833
# 3  Switzerland            7.494           1.564                   0.858
# 4      Finland            7.469           1.441                   0.809
#
#    Freedom  Trust_Government_Corruption  Generosity
# 0    0.635                        0.315       0.362
# 1    0.626                        0.400       0.355
# 2    0.627                        0.153       0.476
# 3    0.620                        0.367       0.290
# 4    0.617                        0.383       0.245

# %% [markdown]
#  Dataset Overview
#
# The dataset includes happiness scores and related factors for 8 countries.

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      8 non-null      object
#  1   Happiness_Score              8 non-null      float64
#  2   GDP_per_Capita               8 non-null      float64
#  3   Health_Life_Expectancy       8 non-null      float64
#  4   Freedom                      8 non-null      float64
#  5   Trust_Government_Corruption  8 non-null      float64
#  6   Generosity                   8 non-null      float64
# dtypes: float64(6), object(1)
# memory usage: 580.0+ bytes
#        Happiness_Score  GDP_per_Capita  Health_Life_Expectancy   Freedom  \
# count         8.000000        8.000000                8.000000  8.000000
# mean          7.441625        1.489375                0.824125  0.618125
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(df['Country'],df['Happiness_Score'],color='skyblue')
plt.xlabel('Country')
plt.ylabel('Happiness_Score')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['GDP_per_Capita'],df['Happiness_Score'],color='green')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('Happiness vs GDP per Capita')
plt.grid(True)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                              Happiness_Score  GDP_per_Capita  \
# Happiness_Score                     1.000000        0.653654
# GDP_per_Capita                      0.653654        1.000000
# Health_Life_Expectancy             -0.495700       -0.116357
# Freedom                             0.527042        0.561852
# Trust_Government_Corruption        -0.040622        0.037491
# Generosity                          0.154016        0.101828
#
#                              Health_Life_Expectancy   Freedom  \
# Happiness_Score                           -0.495700  0.527042
# GDP_per_Capita                            -0.116357  0.561852
# Health_Life_Expectancy                     1.000000  0.058474
# Freedom                                    0.058474  1.000000
# Trust_Government_Corruption               -0.148621  0.049302
# Generosity                                -0.032425  0.344361
#
#                              Trust_Government_Corruption  Generosity
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
df_sorted = df.sort_values(by='Happiness_Score',ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x='Happiness_Score', y= 'Country',data=df_sorted, palette='viridis')
plt.title('Happiness Score by Country')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-15-36de65b8a130>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness_Score', y= 'Country',data=df_sorted, palette='viridis')

# %% [markdown]
# ### ✅ Key Findings
#
# - Countries with higher GDP tend to have higher happiness scores.
# - [Country X] is the happiest among the 8 in the dataset.
# - The correlation heatmap shows positive relationships between GDP and happiness.
#
# This is a basic analysis, but useful as a small project to practice EDA and visualization skills.
